# %%
from Supportingcode.Data_reader import Data
from Supportingcode.Algorithms import rescheduling_problem
import os
import igraph
import pandas as pd

# %%
# import pyomo.environ as pyo
# local = 'Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/'
# logfilepath = local+'LogFiles/'
# local2 = 'Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/CSVFiles/'
# info = Data("3600-input", local, "edb")
# tracks, stations, trains, current_time, maxtime = info.read_from_CSV()
# rescheduling = rescheduling_problem(tracks, stations, trains, current_time, maxtime, "3600-input")
# Alternativeroute_reschedule = rescheduling.Model3(False,2)
# # print(pyo.value(Alternativeroute_reschedule.obj))
# print(Alternativeroute_reschedule)

# %% [markdown]
# ## 1 Hour instances

# %%
local = 'Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/'
logfilepath = local+'LogFiles/'
local2 = 'Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/CSVFiles/'
arquivos = os.listdir(local2)
results1 = pd.DataFrame(columns=["Data", "# of trains", "Objective value", "solution time", "Termination condition", "number pf binary variables"])
results2 = pd.DataFrame(columns=["Data", "# of trains", "Objective value", "solution time", "Termination condition", "number pf binary variables"])
results3 = pd.DataFrame(columns=["Data", "# of trains", "Objective value", "solution time", "# of routes","Termination condition", "number pf binary variables"])
for a in arquivos:
    print('\n',a)
    info = Data(a, local, "edb")
    tracks, stations, trains, current_time, maxtime = info.read_from_CSV()
    rescheduling = rescheduling_problem(tracks, stations, trains, current_time, maxtime, a)
    Fixedroute_reschedule1 = rescheduling.Model1(False, logfilepath)
    results1.loc[len(results1)] = [a, Fixedroute_reschedule1[0], Fixedroute_reschedule1[1], Fixedroute_reschedule1[2], Fixedroute_reschedule1[3], Fixedroute_reschedule1[4]]
    Fixedroute_reschedule2 = rescheduling.Model2(False, logfilepath)
    results2.loc[len(results2)] = [a, Fixedroute_reschedule2[0], Fixedroute_reschedule2[1], Fixedroute_reschedule2[2], Fixedroute_reschedule2[3], Fixedroute_reschedule2[4]]
    Alternativeroute_reschedule = rescheduling.Model3(False, 2, logfilepath)
    results3.loc[len(results3)] = [a, Alternativeroute_reschedule[0], Alternativeroute_reschedule[1], Alternativeroute_reschedule[2], Alternativeroute_reschedule[3], Alternativeroute_reschedule[4], Alternativeroute_reschedule[5]]
pd.DataFrame().to_excel("Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/results.xlsx")
with pd.ExcelWriter("Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/results.xlsx", engine='openpyxl', mode='a') as writer:
    results1.to_excel(writer, sheet_name="Model1", index=False)
    results2.to_excel(writer, sheet_name="Model2", index=False)
    results3.to_excel(writer, sheet_name="Model3", index=False)
# Out:
#  10800-input
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/10800-inputModel1.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/10800-inputModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3411 rows, 811 columns and 6822 nonzeros
# Model fingerprint: 0x32a63761
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 3411 rows and 811 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0771000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.077100000e+04
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/10800-inputModel2.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/10800-inputModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 6045 rows, 3445 columns and 17358 nonzeros
# Model fingerprint: 0x5d739698
# Variable types: 811 continuous, 2634 integer (2634 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 193 rows and 193 columns
# Presolve time: 0.02s
# Presolved: 5852 rows, 3252 columns, 16972 nonzeros
# Variable types: 618 continuous, 2634 integer (2634 binary)
# Found heuristic solution: objective 234525.00000
#
# Root relaxation: objective 7.970000e+03, 1090 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 
#      0     0 11524.4625    0   24 173100.000 11524.4625  93.3%     -    0s
# H    0     0                    12304.000000 11534.8665  6.25%     -    0s
#      0     0 11534.8665    0   29 12304.0000 11534.8665  6.25%     -    0s
#      0     0 11534.8665    0   45 12304.0000 11534.8665  6.25%     -    0s
#      0     0 11559.9354    0   21 12304.0000 11559.9354  6.05%     -    0s
#      0     0 11643.4787    0   26 12304.0000 11643.4787  5.37%     -    0s
#      0     0 11643.4787    0   20 12304.0000 11643.4787  5.37%     -    0s
#      0     0 11643.4787    0   20 12304.0000 11643.4787  5.37%     -    0s
#      0     0 11643.4787    0   19 12304.0000 11643.4787  5.37%     -    0s
#      0     0 11643.4787    0   19 12304.0000 11643.4787  5.37%     -    0s
#      0     0 11644.0927    0   13 12304.0000 11644.0927  5.36%     -    1s
#      0     0 11651.7594    0    9 12304.0000 11651.7594  5.30%     -    1s
#      0     0 11745.2401    0   10 12304.0000 11745.2401  4.54%     -    1s
#      0     0 11791.2173    0   16 12304.0000 11791.2173  4.17%     -    1s
#      0     0 11816.0000    0   18 12304.0000 11816.0000  3.97%     -    1s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 10
#   Implied bound: 181
#   Clique: 3
#   MIR: 44
#   RLT: 13
#   Relax-and-lift: 16
#   BQP: 20
#
# Explored 1 nodes (2601 simplex iterations) in 1.15 seconds (0.58 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 12304 173100
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.230400000000e+04, best bound 1.230400000000e+04, gap 0.0000%
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/14400-inputModel3.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/14400-inputModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 27926 rows, 14861 columns and 136434 nonzeros
# Model fingerprint: 0xd42bd142
# Variable types: 1616 continuous, 13245 integer (13245 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Presolve removed 36 rows and 108 columns
# Presolve time: 0.20s
# Presolved: 27890 rows, 14753 columns, 136290 nonzeros
# Variable types: 1544 continuous, 13209 integer (13209 binary)
# Found heuristic solution: objective 173838.00000
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.683000e+03, 1727 iterations, 0.18 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8683.00000    0   25 173838.000 8683.00000  95.0%     -    2s
#      0     0 8683.00000    0   86 173838.000 8683.00000  95.0%     -    4s
#      0     0 8683.00000    0   59 173838.000 8683.00000  95.0%     -    5s
#      0     0 8683.04632    0   53 173838.000 8683.04632  95.0%     -    6s
#      0     0 8683.04632    0   52 173838.000 8683.04632  95.0%     -    6s
#      0     0 8683.19165    0   51 173838.000 8683.19165  95.0%     -    6s
#      0     0 8683.19165    0   48 173838.000 8683.19165  95.0%     -    7s
#      0     0 8684.10107    0   38 173838.000 8684.10107  95.0%     -    7s
#      0     0 8684.10107    0   38 173838.000 8684.10107  95.0%     -    7s
#      0     0 8685.37004    0   39 173838.000 8685.37004  95.0%     -    7s
#      0     0 8685.37004    0   39 173838.000 8685.37004  95.0%     -    7s
#      0     0 8685.37004    0   39 173838.000 8685.37004  95.0%     -    8s
#      0     0 8687.12164    0   39 173838.000 8687.12164  95.0%     -    8s
#      0     0 8687.12164    0   39 173838.000 8687.12164  95.0%     -    8s
#      0     0 8687.79262    0   37 173838.000 8687.79262  95.0%     -    8s
#      0     0 8687.79262    0   37 173838.000 8687.79262  95.0%     -    8s
#      0     0 8687.79262    0   37 173838.000 8687.79262  95.0%     -    8s
#      0     0 8687.79262    0   37 173838.000 8687.79262  95.0%     -    8s
#   4940  1525     cutoff   49      9521.99998 7712.99998  19.0%  37.1   40s
#   6014  1948 9373.99999   51  381 9521.99998 7712.99998  19.0%  40.6   45s
#   7148  2401 9407.99997   54  380 9521.99998 7712.99998  19.0%  42.2   50s
#   8244  3034 9401.99999   48  396 9521.99998 7712.99998  19.0%  43.3   55s
#   9229  3586 8697.00000   26  534 9521.99998 7712.99998  19.0%  44.1   60s
#  11146  4458 9123.02852   29  539 9521.99998 7793.32005  18.2%  45.1   66s
#  12075  4738 9402.99999   42  385 9521.99998 7882.99999  17.2%  45.7   70s
#  12888  5067 9126.99999   34   35 9521.99998 7949.99999  16.5%  46.0   75s
#  12958  5109 8664.00000   34   20 9521.99998 7949.99999  16.5%  47.5   80s
#  13990  5411 9143.00510   42   21 9521.99998 7949.99999  16.5%  48.1   85s
#  15585  5572     cutoff   36      9521.99998 8100.99999  14.9%  48.0   90s
#
# Cutting planes:
#   Learned: 39
#   Gomory: 3
#   Implied bound: 432
#   MIR: 2
#
# Explored 15602 nodes (850632 simplex iterations) in 90.06 seconds (85.85 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 9522 9522 9526 ... 232326
#
# Time limit reached
# Warning: max constraint violation (3.2727e-06) exceeds tolerance
# Best objective 9.521999966899e+03, best bound 8.100999993869e+03, gap 14.9233%
# Set parameter LogFile to value ""
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
#
#  21600-input
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/21600-inputModel1.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/21600-inputModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1873 rows, 579 columns and 3746 nonzeros
# Model fingerprint: 0xfaa5ab2b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 1873 rows and 579 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.8970000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.897000000e+03
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/21600-inputModel2.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/21600-inputModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3191 rows, 1897 columns and 9018 nonzeros
# Model fingerprint: 0x1ad489c7
# Variable types: 579 continuous, 1318 integer (1318 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 135 rows and 135 columns
# Presolve time: 0.01s
# Presolved: 3056 rows, 1762 columns, 8748 nonzeros
# Variable types: 444 continuous, 1318 integer (1318 binary)
# Found heuristic solution: objective 164263.00000
#
# Root relaxation: objective 5.435000e+03, 902 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5435.00000    0   20 164263.000 5435.00000  96.7%     -    0s
# H    0     0                    6695.0000000 5435.00000  18.8%     -    0s
# H    0     0                    6599.0000000 5435.00000  17.6%     -    0s
#      0     0     cutoff    0      6599.00000 6599.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 21
#   MIR: 5
#   RLT: 7
#   BQP: 18
#
# Explored 1 nodes (990 simplex iterations) in 0.10 seconds (0.05 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 6599 6695 164263
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.599000000000e+03, best bound 6.598999999999e+03, gap 0.0000%
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/21600-inputModel3.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/21600-inputModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 12060 rows, 6637 columns and 58136 nonzeros
# Model fingerprint: 0x9b9eacd4
# Variable types: 1094 continuous, 5543 integer (5543 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+04]
# Presolve removed 24 rows and 72 columns
# Presolve time: 0.04s
# Presolved: 12036 rows, 6565 columns, 58040 nonzeros
# Variable types: 1046 continuous, 5519 integer (5519 binary)
# Found heuristic solution: objective 169347.00000
#
# Root relaxation: objective 5.435000e+03, 1123 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5435.00000    0   19 169347.000 5435.00000  96.8%     -    0s
# H    0     0                    169167.00000 5435.00000  96.8%     -    0s
#      0     0 5435.00000    0   25 169167.000 5435.00000  96.8%     -    1s
#      0     0 5435.00000    0   22 169167.000 5435.00000  96.8%     -    1s
#      0     0 5438.99999    0   24 169167.000 5438.99999  96.8%     -    1s
#      0     0 5438.99999    0   23 169167.000 5438.99999  96.8%     -    1s
#      0     0 5438.99999    0   22 169167.000 5438.99999  96.8%     -    1s
#      0     0 5438.99999    0   22 169167.000 5438.99999  96.8%     -    1s
#      0     2 5438.99999    0   22 169167.000 5438.99999  96.8%     -    1s
# H   31    38                    168987.00000 5438.99999  96.8%  46.9    2s
# H   34    38                    168969.00000 5438.99999  96.8%  51.2    2s
# H   66    70                    168814.99996 5438.99999  96.8%  43.5    2s
# H   68    70                    168788.99996 5438.99999  96.8%  43.8    2s
# *  128   134              17    6622.9999843 5438.99999  17.9%  45.2    2s
# H  180   144                    6612.9999862 5438.99999  17.8%  42.8    2s
# H  265   203                    6598.9999903 5438.99999  17.6%  39.0    3s
# *  600   377              16    6598.9999835 5438.99999  17.6%  36.8    4s
#    913   523 6198.99998   16    7 6598.99998 5439.65597  17.6%  36.7    5s
#   2368  1070     cutoff   46      6598.99998 5447.34588  17.5%  12.2   10s
#   5262  1461     cutoff   27      6598.99998 5922.99999  10.2%  25.5   15s
#   8409  2580 6491.00539   28    5 6598.99998 6070.99999  8.00%  29.7   20s
#  11129  3454 6354.99999   31   13 6598.99998 6125.00000  7.18%  34.1   25s
#  14157  4273 6588.99999   28  111 6598.99998 6202.99999  6.00%  37.1   30s
#  16884  4606     cutoff   31      6598.99998 6244.99999  5.36%  39.2   35s
#  19987  4583     cutoff   29      6598.99998 6312.99999  4.33%  38.6   40s
#  23425  3969 6585.00000   29   25 6598.99998 6394.99999  3.09%  39.1   45s
#  26083  3591     cutoff   28      6598.99998 6427.18791  2.60%  39.3   50s
#
# Cutting planes:
#   Learned: 26
#   Cover: 1
#   Implied bound: 483
#   MIR: 2
#
# Explored 27275 nodes (1190191 simplex iterations) in 90.15 seconds (55.59 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 6599 6599 6599 ... 169167
#
# Time limit reached
# Warning: max constraint violation (5.0787e-06) exceeds tolerance
# Best objective 6.598999972250e+03, best bound 6.454999990500e+03, gap 2.1821%
# Set parameter LogFile to value ""
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
#
#  25200-input
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/25200-inputModel1.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/25200-inputModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1402 rows, 504 columns and 2804 nonzeros
# Model fingerprint: 0x73e49a0c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 1402 rows and 504 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9980000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.998000000e+03
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/25200-inputModel2.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/25200-inputModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2321 rows, 1423 columns and 6480 nonzeros
# Model fingerprint: 0xacef9bfe
# Variable types: 504 continuous, 919 integer (919 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 117 rows and 117 columns
# Presolve time: 0.01s
# Presolved: 2204 rows, 1306 columns, 6246 nonzeros
# Variable types: 387 continuous, 919 integer (919 binary)
# Found heuristic solution: objective 142571.00000
#
# Root relaxation: objective 4.428000e+03, 622 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4428.00000    0    5 142571.000 4428.00000  96.9%     -    0s
# H    0     0                    5502.0000000 4428.00000  19.5%     -    0s
# H    0     0                    5158.0000000 4428.00000  14.2%     -    0s
# H    0     0                    4998.0000000 4428.00000  11.4%     -    0s
#      0     0 4919.96948    0    6 4998.00000 4919.96948  1.56%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   RLT: 4
#   BQP: 3
#
# Explored 1 nodes (664 simplex iterations) in 0.07 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 4998 5158 5502 142571
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.998000000000e+03, best bound 4.998000000000e+03, gap 0.0000%
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/25200-inputModel3.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/25200-inputModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 8620 rows, 4839 columns and 41215 nonzeros
# Model fingerprint: 0xec2933ac
# Variable types: 953 continuous, 3886 integer (3886 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+04]
# Presolve removed 21 rows and 63 columns
# Presolve time: 0.03s
# Presolved: 8599 rows, 4776 columns, 41131 nonzeros
# Variable types: 911 continuous, 3865 integer (3865 binary)
# Found heuristic solution: objective 146481.00000
#
# Root relaxation: objective 4.428000e+03, 749 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4428.00000    0   17 146481.000 4428.00000  97.0%     -    0s
# H    0     0                    146403.00000 4428.00000  97.0%     -    0s
#      0     0 4428.00000    0   28 146403.000 4428.00000  97.0%     -    0s
#      0     0 4428.00000    0   25 146403.000 4428.00000  97.0%     -    0s
#      0     0 4428.00000    0   14 146403.000 4428.00000  97.0%     -    0s
#      0     0 4432.00000    0    5 146403.000 4432.00000  97.0%     -    1s
#      0     0 4432.00000    0    5 146403.000 4432.00000  97.0%     -    1s
#      0     0 4432.00000    0    6 146403.000 4432.00000  97.0%     -    1s
# H    0     0                    146329.00000 4432.00000  97.0%     -    1s
#      0     0 4432.00000    0    6 146329.000 4432.00000  97.0%     -    1s
#      0     0 4432.00000    0    6 146329.000 4432.00000  97.0%     -    1s
#      0     0 4432.00000    0    6 146329.000 4432.00000  97.0%     -    1s
# H    0     0                    146325.00000 4432.00000  97.0%     -    1s
#      0     0 4432.00000    0    6 146325.000 4432.00000  97.0%     -    1s
# H    0     0                    5004.9999732 4432.00000  11.4%     -    1s
#      0     0 4432.00000    0    5 5004.99997 4432.00000  11.4%     -    1s
#      0     0 4432.00000    0    5 5004.99997 4432.00000  11.4%     -    1s
# H    0     0                    4997.9999778 4432.00000  11.3%     -    1s
#      0     2 4432.00000    0    5 4997.99998 4432.00000  11.3%     -    1s
# *  268    96              14    4997.9999771 4491.09178  10.1%  28.9    2s
# *  469   104              11    4997.9999761 4554.99999  8.86%  28.2    2s
#
# Cutting planes:
#   Learned: 29
#   Gomory: 4
#   Cover: 34
#   Implied bound: 587
#   MIR: 43
#
# Explored 1218 nodes (41936 simplex iterations) in 3.39 seconds (2.89 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 4998 4998 4998 ... 146481
# No other solutions better than 4998
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (5.3906e-06) exceeds tolerance
# Best objective 4.997999963445e+03, best bound 4.997999963445e+03, gap 0.0000%
# Set parameter LogFile to value ""
#
#  28800-input
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/28800-inputModel1.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/28800-inputModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1435 rows, 529 columns and 2870 nonzeros
# Model fingerprint: 0xc6d9f26a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 1435 rows and 529 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.9130000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.913000000e+03
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/28800-inputModel2.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/28800-inputModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2363 rows, 1457 columns and 6582 nonzeros
# Model fingerprint: 0x808247ba
# Variable types: 529 continuous, 928 integer (928 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 124 rows and 124 columns
# Presolve time: 0.01s
# Presolved: 2239 rows, 1333 columns, 6334 nonzeros
# Variable types: 405 continuous, 928 integer (928 binary)
# Found heuristic solution: objective 72896.000000
#
# Root relaxation: objective 4.951000e+03, 230 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4951.00000    0    6 72896.0000 4951.00000  93.2%     -    0s
# H    0     0                    5721.0000000 4951.00000  13.5%     -    0s
#      0     0     cutoff    0      5721.00000 5721.00000  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 4
#   MIR: 1
#   RLT: 1
#   Relax-and-lift: 1
#   BQP: 5
#
# Explored 1 nodes (272 simplex iterations) in 0.08 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 5721 72896
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.721000000000e+03, best bound 5.721000000000e+03, gap 0.0000%
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/28800-inputModel3.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/28800-inputModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 8668 rows, 4889 columns and 41362 nonzeros
# Model fingerprint: 0x9428289c
# Variable types: 1000 continuous, 3889 integer (3889 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+04]
# Presolve removed 22 rows and 66 columns
# Presolve time: 0.03s
# Presolved: 8646 rows, 4823 columns, 41274 nonzeros
# Variable types: 956 continuous, 3867 integer (3867 binary)
# Found heuristic solution: objective 73190.000000
#
# Root relaxation: objective 4.951000e+03, 881 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4951.00000    0    9 73190.0000 4951.00000  93.2%     -    0s
# H    0     0                    73091.999999 4951.00000  93.2%     -    0s
#      0     0 4951.00000    0   23 73092.0000 4951.00000  93.2%     -    0s
#      0     0 4951.00000    0   15 73092.0000 4951.00000  93.2%     -    0s
#      0     0 4951.00823    0    7 73092.0000 4951.00823  93.2%     -    0s
#      0     0 4951.03864    0    6 73092.0000 4951.03864  93.2%     -    0s
#      0     0 4951.03864    0    7 73092.0000 4951.03864  93.2%     -    0s
#      0     0 4951.04182    0    7 73092.0000 4951.04182  93.2%     -    1s
#      0     0 4951.10710    0    6 73092.0000 4951.10710  93.2%     -    1s
#      0     0 4951.10710    0    6 73092.0000 4951.10710  93.2%     -    1s
#      0     2 4951.10710    0    6 73092.0000 4951.10710  93.2%     -    1s
# H   33    38                    5824.9999774 4983.63856  14.4%  23.1    1s
# H   34    38                    5788.9999800 4983.63856  13.9%  22.9    1s
# H  127    91                    5772.9999849 4983.63856  13.7%  23.7    1s
# *  245   144              15    5727.9999849 4990.99998  12.9%  25.5    1s
# H  560   177                    5723.9999894 5334.99998  6.80%  29.1    2s
# *  584   181              14    5720.9999850 5334.99998  6.75%  29.9    2s
#
# Cutting planes:
#   Learned: 22
#   Gomory: 3
#   Cover: 25
#   Implied bound: 300
#   MIR: 55
#
# Explored 2749 nodes (85757 simplex iterations) in 4.98 seconds (4.63 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 5721 5721 5724 ... 73190
# No other solutions better than 5721
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (5.9469e-06) exceeds tolerance
# Best objective 5.720999982280e+03, best bound 5.720999982280e+03, gap 0.0000%
# Set parameter LogFile to value ""
#
#  32400-input
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/32400-inputModel1.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/32400-inputModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1293 rows, 482 columns and 2586 nonzeros
# Model fingerprint: 0x021a57fb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 1293 rows and 482 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1350000e+03   0.000000e+00   0.000000e+00      0s
#
# ...
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/68400-inputModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1716 rows, 1086 columns and 4728 nonzeros
# Model fingerprint: 0xd53db860
# Variable types: 438 continuous, 648 integer (648 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+04]
# Presolve removed 99 rows and 99 columns
# Presolve time: 0.01s
# Presolved: 1617 rows, 987 columns, 4530 nonzeros
# Variable types: 339 continuous, 648 integer (648 binary)
# Found heuristic solution: objective 68945.000000
#
# Root relaxation: objective 3.398000e+03, 237 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3398.00000    0    2 68945.0000 3398.00000  95.1%     -    0s
# H    0     0                    3852.0000000 3398.00000  11.8%     -    0s
# H    0     0                    3615.0000000 3398.00000  6.00%     -    0s
#      0     0 3398.00000    0    2 3615.00000 3398.00000  6.00%     -    0s
#
# Explored 1 nodes (237 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 3615 3852 68945
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.615000000000e+03, best bound 3.615000000000e+03, gap 0.0000%
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/68400-inputModel3.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/68400-inputModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 6245 rows, 3582 columns and 29585 nonzeros
# Model fingerprint: 0xd635fad2
# Variable types: 829 continuous, 2753 integer (2753 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+05]
# Presolve removed 18 rows and 54 columns
# Presolve time: 0.02s
# Presolved: 6227 rows, 3528 columns, 29513 nonzeros
# Variable types: 793 continuous, 2735 integer (2735 binary)
# Found heuristic solution: objective 68945.000000
# Found heuristic solution: objective 68944.999939
#
# Root relaxation: objective 3.398000e+03, 751 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3398.00000    0    8 68944.9999 3398.00000  95.1%     -    0s
#      0     0 3398.00000    0   17 68944.9999 3398.00000  95.1%     -    0s
#      0     0 3398.00000    0    9 68944.9999 3398.00000  95.1%     -    0s
#      0     0 3398.00000    0    7 68944.9999 3398.00000  95.1%     -    0s
#      0     0 3398.00000    0    8 68944.9999 3398.00000  95.1%     -    0s
#      0     0 3398.00000    0    8 68944.9999 3398.00000  95.1%     -    0s
# H    0     0                    3617.9999949 3398.00000  6.08%     -    0s
#      0     0 3398.00000    0    5 3617.99999 3398.00000  6.08%     -    0s
# H    0     0                    3615.0000000 3398.00000  6.00%     -    0s
#      0     2 3398.00000    0    5 3615.00000 3398.00000  6.00%     -    0s
# *    7     4               3    3614.9999949 3398.00362  6.00%  25.9    0s
#
# Cutting planes:
#   Learned: 13
#   Gomory: 3
#   Implied bound: 187
#   MIR: 23
#   Relax-and-lift: 7
#
# Explored 17 nodes (5179 simplex iterations) in 0.76 seconds (0.57 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 3615 3615 3618 ... 68945
# No other solutions better than 3615
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (8.1549e-06) exceeds tolerance
# Best objective 3.614999983532e+03, best bound 3.614999983532e+03, gap 0.0000%
# Set parameter LogFile to value ""
#
#  7200-input
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/7200-inputModel1.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/7200-inputModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2243 rows, 620 columns and 4486 nonzeros
# Model fingerprint: 0xf8e5b8d3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+03]
# Presolve removed 2243 rows and 620 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.5060000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.506000000e+03
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/7200-inputModel2.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/7200-inputModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3892 rows, 2269 columns and 11082 nonzeros
# Model fingerprint: 0xbf57498a
# Variable types: 620 continuous, 1649 integer (1649 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+03]
# Presolve removed 148 rows and 148 columns
# Presolve time: 0.01s
# Presolved: 3744 rows, 2121 columns, 10786 nonzeros
# Variable types: 472 continuous, 1649 integer (1649 binary)
# Found heuristic solution: objective 164960.00000
#
# Root relaxation: objective 6.346000e+03, 992 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6346.00000    0    3 164960.000 6346.00000  96.2%     -    0s
# H    0     0                    6506.0000000 6346.00000  2.46%     -    0s
#      0     0 6346.00000    0    3 6506.00000 6346.00000  2.46%     -    0s
#
# Explored 1 nodes (992 simplex iterations) in 0.07 seconds (0.04 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 6506 164960
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.506000000000e+03, best bound 6.506000000000e+03, gap 0.0000%
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/7200-inputModel3.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/7200-inputModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 14804 rows, 8051 columns and 71710 nonzeros
# Model fingerprint: 0x9330763c
# Variable types: 1168 continuous, 6883 integer (6883 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 26 rows and 78 columns
# Presolve time: 0.06s
# Presolved: 14778 rows, 7973 columns, 71606 nonzeros
# Variable types: 1116 continuous, 6857 integer (6857 binary)
# Found heuristic solution: objective 168562.00000
#
# Root relaxation: objective 6.346000e+03, 1033 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6346.00000    0   15 168562.000 6346.00000  96.2%     -    0s
# H    0     0                    168454.00000 6346.00000  96.2%     -    1s
# H    0     0                    168382.00000 6346.00000  96.2%     -    1s
#      0     0 6346.00000    0   46 168382.000 6346.00000  96.2%     -    1s
#      0     0 6346.00000    0   18 168382.000 6346.00000  96.2%     -    1s
#      0     0 6346.04270    0    6 168382.000 6346.04270  96.2%     -    1s
#      0     0 6347.06931    0   15 168382.000 6347.06931  96.2%     -    1s
#      0     0 6347.06931    0   15 168382.000 6347.06931  96.2%     -    2s
#      0     0 6348.32765    0   11 168382.000 6348.32765  96.2%     -    2s
# H    0     0                    168288.00000 6349.05748  96.2%     -    2s
#      0     0 6349.05748    0    8 168288.000 6349.05748  96.2%     -    2s
#      0     0 6349.09836    0    8 168288.000 6349.09836  96.2%     -    2s
#      0     0 6349.19672    0    7 168288.000 6349.19672  96.2%     -    2s
#      0     0 6349.19672    0    6 168288.000 6349.19672  96.2%     -    2s
#      0     0 6349.19672    0    5 168288.000 6349.19672  96.2%     -    2s
# H    0     0                    6508.9999943 6349.19672  2.46%     -    2s
#      0     0 6349.19672    0    4 6508.99999 6349.19672  2.46%     -    2s
#      0     0 6349.20898    0    7 6508.99999 6349.20898  2.45%     -    2s
#      0     0 6349.22996    0    7 6508.99999 6349.22996  2.45%     -    2s
#      0     0 6349.22996    0    7 6508.99999 6349.22996  2.45%     -    2s
#      0     0 6351.00000    0    5 6508.99999 6351.00000  2.43%     -    2s
#      0     0 6351.00000    0    5 6508.99999 6351.00000  2.43%     -    2s
#      0     0 6353.00000    0    3 6508.99999 6353.00000  2.40%     -    3s
# H    0     0                    6505.9999962 6353.06301  2.35%     -    3s
#      0     0 6353.06301    0    6 6506.00000 6353.06301  2.35%     -    3s
#      0     0 6353.06301    0    6 6506.00000 6353.06301  2.35%     -    3s
#      0     0 6353.06301    0    6 6506.00000 6353.06301  2.35%     -    3s
#      0     0 6353.12015    0    6 6506.00000 6353.12015  2.35%     -    3s
#      0     2 6353.12015    0    6 6506.00000 6353.12015  2.35%     -    3s
# H   71    19                    6505.9999949 6438.99999  1.03%  48.4    3s
#
# Cutting planes:
#   Learned: 34
#   Gomory: 7
#   Cover: 7
#   Implied bound: 468
#   MIR: 53
#
# Explored 144 nodes (19082 simplex iterations) in 3.93 seconds (3.16 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 6506 6506 6509 ... 168562
# No other solutions better than 6506
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.505999982864e+03, best bound 6.505999982864e+03, gap 0.0000%
# Set parameter LogFile to value ""
#
#  72000-input
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/72000-inputModel1.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/72000-inputModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 102 rows, 75 columns and 204 nonzeros
# Model fingerprint: 0xef5f5c07
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 7e+04]
# Presolve removed 102 rows and 75 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1600000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.160000000e+02
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/72000-inputModel2.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/72000-inputModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 132 rows, 105 columns and 324 nonzeros
# Model fingerprint: 0x4a4a7c97
# Variable types: 75 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 7e+04]
# Found heuristic solution: objective 416.0000000
# Presolve removed 30 rows and 36 columns
# Presolve time: 0.00s
# Presolved: 102 rows, 69 columns, 252 nonzeros
# Variable types: 45 continuous, 24 integer (24 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 416
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.160000000000e+02, best bound 4.160000000000e+02, gap 0.0000%
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/72000-inputModel3.log"
# Solver log file: Data/1-hour-interval-madrid/1-hour-interval-madrid/testsuite/LogFiles/72000-inputModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 390 rows, 274 columns and 1667 nonzeros
# Model fingerprint: 0x1d9a70fb
# Variable types: 143 continuous, 131 integer (131 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+05]
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 385 rows, 262 columns, 1649 nonzeros
# Variable types: 134 continuous, 128 integer (128 binary)
# Found heuristic solution: objective 6431.0000000
#
# Root relaxation: objective 3.010993e+02, 81 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  301.09928    0    3 6431.00000  301.09928  95.3%     -    0s
# H    0     0                    6356.0000000  301.09928  95.3%     -    0s
# H    0     0                     455.9999992  301.09928  34.0%     -    0s
# H    0     0                     416.0000000  301.09928  27.6%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Implied bound: 78
#   MIR: 6
#   Relax-and-lift: 3
#
# Explored 1 nodes (81 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 416 456 6356 6431
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.160000000000e+02, best bound 4.160000000000e+02, gap 0.0000%
# Set parameter LogFile to value ""

# %% [markdown]
# ## Complete schedule instance

# %%
local = 'Data/complete-madrid-instance/'
logfilepath = local+'LogFiles/'
results1 = pd.DataFrame(columns=["Data", "# of trains", "Objective value", "solution time", "Termination condition", "number pf binary variables"])
results2 = pd.DataFrame(columns=["Data", "# of trains", "Objective value", "solution time", "Termination condition", "number pf binary variables"])
results3 = pd.DataFrame(columns=["Data", "# of trains", "Objective value", "solution time", "# of routes", "Termination condition", "number pf binary variables"])
info = Data("madrid_current_schedule.edb", local, "edb")
tracks, stations, trains, current_time, maxtime = info.read_from_CSV()
a = "Complete schedule"
rescheduling = rescheduling_problem(tracks, stations, trains, current_time, maxtime, a)
Fixedroute_reschedule1 = rescheduling.Model1(False, logfilepath)
results1.loc[len(results1)] = [a, Fixedroute_reschedule1[0], Fixedroute_reschedule1[1], Fixedroute_reschedule1[2], Fixedroute_reschedule1[3], Fixedroute_reschedule1[4]]
Fixedroute_reschedule2 = rescheduling.Model2(False, logfilepath)
results2.loc[len(results2)] = [a, Fixedroute_reschedule2[0], Fixedroute_reschedule2[1], Fixedroute_reschedule2[2], Fixedroute_reschedule2[3], Fixedroute_reschedule2[4]]
Alternativeroute_reschedule = rescheduling.Model3(False,2, logfilepath)
results3.loc[len(results3)] = [a, Alternativeroute_reschedule[0], Alternativeroute_reschedule[1], Alternativeroute_reschedule[2], Alternativeroute_reschedule[3], Alternativeroute_reschedule[4], Alternativeroute_reschedule[5]]
pd.DataFrame().to_excel("Data/complete-madrid-instance/results.xlsx")
with pd.ExcelWriter("Data/complete-madrid-instance/results.xlsx", engine='openpyxl', mode='a') as writer:
    results1.to_excel(writer, sheet_name="Model1", index=False)
    results2.to_excel(writer, sheet_name="Model2", index=False)
    results3.to_excel(writer, sheet_name="Model3", index=False)
# Out:
# Set parameter LogFile to value "Data/complete-madrid-instance/LogFiles/Complete scheduleModel1.log"
# Solver log file: Data/complete-madrid-instance/LogFiles/Complete scheduleModel1.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 551627 rows, 11362 columns and 1103254 nonzeros
# Model fingerprint: 0xf9c5eff6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 7e+04]
# Presolve removed 551627 rows and 11362 columns
# Presolve time: 2.61s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2949100e+05   0.000000e+00   0.000000e+00      3s
#
# Solved in 0 iterations and 2.78 seconds (2.12 work units)
# Optimal objective  1.294910000e+05
# Set parameter LogFile to value ""
# Set parameter LogFile to value "Data/complete-madrid-instance/LogFiles/Complete scheduleModel2.log"
# Solver log file: Data/complete-madrid-instance/LogFiles/Complete scheduleModel2.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1092367 rows, 552102 columns and 3266214 nonzeros
# Model fingerprint: 0xe2adabdc
# Variable types: 11362 continuous, 540740 integer (540740 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+04]
# Presolve removed 2538 rows and 2538 columns (presolve time = 5s) ...
# Presolve removed 2680 rows and 2680 columns
# Presolve time: 9.90s
# Presolved: 1089687 rows, 549422 columns, 3260854 nonzeros
# Variable types: 8682 continuous, 540740 integer (540740 binary)
# Found heuristic solution: objective 7.943797e+07
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 4.68s
#
# Barrier performed 0 iterations in 56.64 seconds (29.92 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.21s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.072680e+05, 208 iterations, 16.16 seconds (6.81 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 107268.000    0  229 7.9438e+07 107268.000   100%     -   61s
#
# Explored 1 nodes (473 simplex iterations) in 147.79 seconds (54.96 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 7.9438e+07
#
# Time limit reached
# Best objective 7.943796800000e+07, best bound 1.072680000000e+05, gap 99.8650%
# Set parameter LogFile to value ""
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
# Set parameter LogFile to value "Data/complete-madrid-instance/LogFiles/Complete scheduleModel3.log"
# Solver log file: Data/complete-madrid-instance/LogFiles/Complete scheduleModel3.log
# Set parameter TimeLimit to value 90
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4498504 rows, 2261161 columns and 22450109 nonzeros
# Model fingerprint: 0xc6ade363
# Variable types: 21443 continuous, 2239718 integer (2239718 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+05]
# Presolve removed 478 rows and 1426 columns (presolve time = 5s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 10s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 15s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 20s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 25s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 30s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 35s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 40s) ...
# Presolve removed 478 rows and 1426 columns (presolve time = 45s) ...
# Presolve removed 478 rows and 1426 columns
# Presolve time: 45.40s
# Presolved: 4498026 rows, 2259735 columns, 22448202 nonzeros
# Variable types: 20492 continuous, 2239243 integer (2239243 binary)
#
# Explored 0 nodes (0 simplex iterations) in 90.74 seconds (80.59 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.060080000000e+05, gap -
# Set parameter LogFile to value ""
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
# ERROR: evaluating object as numeric value: delays[1,9]
#         (object: <class 'pyomo.core.base.var.VarData'>)
#     No value for uninitialized NumericValue object delays[1,9]
# ERROR: evaluating object as numeric value: obj
#         (object: <class 'pyomo.core.base.objective.ScalarObjective'>)
#     No value for uninitialized NumericValue object delays[1,9]
